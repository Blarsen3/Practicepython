# %% [markdown]
# # CHP 6 Algorithim workbench questions

# %% [markdown]
# ## Question 1:
# Write a program that opens an output file with the filename my_name.txt, writes your name to the file, then closes the file.

# %% [markdown]
# ### First you wnat to identify the file name and and then you want to open the file in write mode which I will show below.

# %%
# Define the filename
filename = "my_name.txt"

# Open the file in write mode
with open(filename, "w") as file:
# Out:
#   Cell In[1], line 5
#     with open(filename, "w") as file:
#                                      ^
# SyntaxError: incomplete input

# %% [markdown]
# ## Prediction is that this code will not work because it doesnt have a file to call back to and it doesnt know what to write

# %% [markdown]
# ### With taht now we add the final thing for the input to say and store which will be my name.

# %%
# Define the filename
filename = "my_name.txt"

# Open the file in write mode
with open(filename, "w") as file:
    # Write your name to the file
    file.write("Bobby Larsen")

# The file is automatically closed when the with block is exited

# %% [markdown]
# ### I predict this will work and thsi will store my code and name in the file.
