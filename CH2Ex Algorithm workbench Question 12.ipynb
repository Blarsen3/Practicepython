# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# ## Algorithm Workbench - Number 12
# Were presented with a print function call and asked what the output will be.

# %%
print('George', 'John', 'Paul', 'Ringo', sep='@')
# Out:
# George@John@Paul@Ringo

# %% [markdown]
# I belive that the output will be similar to the following string:
#
# "George@John@Paul@Ringo"

# %% [markdown]
# As you can see my prediction was right because they used a @ for the space values instead of using ' ' so it replaced the spaces with the @ symbol.
