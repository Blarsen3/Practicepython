# %% [markdown]
# # CHP 10 Exs.
# ## Programming exercise #s

# %% [markdown]
# # Question 3: Personal information class.
# Design a class that holds the following personal data: name, address, age, and phone number. Write appropriate accessor and mutator methods. Also, write a program that creates three instances of the class. One instance should hold your information, and the other two should hold your friends’ or family members’ information.

# %% [markdown]
# ### So the first thing it wants us to do is to define and make a class to hold specific information. Lets begin with that below and just focus on the first part.

# %% [markdown]
# ### We also want to define the name and address etc

# %%
class PersonalData:
    def __init__(self, name, address, age, phone_number):
        self._name = name 
        self._address = address
        self._age = age 
        self._phone_number = phone_number

    # accessor method (Getters) 
    def get_name(self):
        return self._name

    def get_address(self):
        return self._address

    def get_age(self):
        return self._age

    def get_phone_number(self):
        return self._phone_number

    # Mutator methods (setters)
    def set_name(self, name):
        self._name = name

    def set_address(self, address):
        self._address = address

    def set_age(self, age):
        self._age = age 

    def set_phone_number(self, phone_number):
        self._phone_number = phone_number

# %% [markdown]
# ### CHeckpoint/prediction: This is my first set of code I have to add more to it because this just identifies the class and my next set of code will do more and I will explain below. But this is just to identify the class.

# %% [markdown]
# ## Now below I will start the code that will make the instances for this problem. I will show and explain below what and why I do it

# %%
class PersonalData:
    def __init__(self, name, address, age, phone_number):
        self._name = name
        self._address = address
        self._age = age
        self._phone_number = phone_number
    
    # Accessor methods (getters)
    def get_name(self):
        return self._name
    
    def get_address(self):
        return self._address
    
    def get_age(self):
        return self._age
    
    def get_phone_number(self):
        return self._phone_number
    
    # Mutator methods (setters)
    def set_name(self, name):
        self._name = name
    
    def set_address(self, address):
        self._address = address
    
    def set_age(self, age):
        self._age = age
    
    def set_phone_number(self, phone_number):
        self._phone_number = phone_number

def main():
    # Creating instances of PersonalData class
    person1 = PersonalData("Your Name", "Your Address", 30, "123-456-7890")
    person2 = PersonalData("Friend 1", "Friend 1's Address", 25, "111-222-3333")
    person3 = PersonalData("Friend 2", "Friend 2's Address", 28, "444-555-6666")
    
    # Printing information using accessor methods
    print("Person 1:")
    print("Name:", person1.get_name())
    print("Address:", person1.get_address())
    print("Age:", person1.get_age())
    print("Phone Number:", person1.get_phone_number())
    print()
    
    print("Person 2:")
    print("Name:", person2.get_name())
    print("Address:", person2.get_address())
    print("Age:", person2.get_age())
    print("Phone Number:", person2.get_phone_number())
    print()
    
    print("Person 3:")
    print("Name:", person3.get_name())
    print("Address:", person3.get_address())
    print("Age:", person3.get_age())
    print("Phone Number:", person3.get_phone_number())

if __name__ == "__main__":
    main()
# Out:
# Person 1:
# Name: Your Name
# Address: Your Address
# Age: 30
# Phone Number: 123-456-7890
#
# Person 2:
# Name: Friend 1
# Address: Friend 1's Address
# Age: 25
# Phone Number: 111-222-3333
#
# Person 3:
# Name: Friend 2
# Address: Friend 2's Address
# Age: 28
# Phone Number: 444-555-6666

# %% [markdown]
# ### My prediction for this is that this code will work and it will collect personal information from your friends and will keep the information and display it when needed

# %% [markdown]
# ### after trying the code All you have to do now is make an acess point to type in what information you want to be displayed and what you want to be shown I just did the base template for this !

# %% [markdown]
# ## Below I will show you the process it took me to do this with a flow chart

# %%
Start

  |
  v
main() Function
  |
  v
Create person1: "Your Name", "Your Address", 30, "123-456-7890"
  |
  v
Create person2: "Friend 1", "Friend 1's Address", 25, "111-222-3333"
  |
  v
Create person3: "Friend 2", "Friend 2's Address", 28, "444-555-6666"
  |
  v
Print "Person 1:"
  |
  v
Print "Name:", person1.get_name()
  |
  v
Print "Address:", person1.get_address()
  |
  v
Print "Age:", person1.get_age()
  |
  v
Print "Phone Number:", person1.get_phone_number()
  |
  v
Print newline
  |
  v
Print "Person 2:"
  |
  v
Print "Name:", person2.get_name()
  |
  v
Print "Address:", person2.get_address()
  |
  v
Print "Age:", person2.get_age()
  |
  v
Print "Phone Number:", person2.get_phone_number()
  |
  v
Print newline
  |
  v
Print "Person 3:"
  |
  v
Print "Name:", person3.get_name()
  |
  v
Print "Address:", person3.get_address()
  |
  v
Print "Age:", person3.get_age()
  |
  v
Print "Phone Number:", person3.get_phone_number()
  |
  v
End
# Out:
#   Cell In[19], line 3
#     |
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Programming ex: question 5: RetailItem class
# Write a class named RetailItem that holds data about an item in a retail store. The class should store the following data in attributes: item description, units in inventory, and price.Once you have written the class, write a program that creates three RetailItem objects and stores the following data in them

# %% [markdown]
# ## First we are going to want to create the class for retailitem and make sure it has all the values we need before defining the main lets do that below

# %%
class RetailItem:
    def __init__(self, description, units_in_inventory, price):
        self.description = description
        self.units_in_inventory = units_in_inventory
        self.price = price
    
    def __str__(self):
        return f"Description: {self.description}, Units in Inventory: {self.units_in_inventory}, Price: ${self.price:.2f}"
# Out:
#   Cell In[24], line 3
#
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# ### Checkpoint/Prediction: This is identifying the class which will help us have a class that already has information in it now we can move on to the retail and money side of it
