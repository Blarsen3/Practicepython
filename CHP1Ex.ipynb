# %% [markdown]
# # Chapter 1 Ex.
# Problems 1, 3, 4

# %% [markdown]
# ## Ex 1.

# %%
print('This is a test of the Python interpreter.')
# Out:
# This is a test of the Python interpreter.

# %%
print("The number to the right should be 5:", 5)
# Out:
# The number to the right should be 5: 5

# %% [markdown]
# ## Ex 3.
# Binary code for 11,65,100,255
#
# 11= 1011
#
# 65= 100001
#
# 100= 1100100
#
# 255= 11111111
#
# I started by dividing all the numbers by two and keep going down the list thats how I went from real nubers to binary. EX 11/2= 5 R=1 etc...

# %% [markdown]
# ## Ex 4.

# %% [markdown]
# Binary code to numbers.

# %% [markdown]
# 1101, 1000, 101011
#
# 1101 = 13
#
# 1000 = 8
#
# 101011 = 43
#
# For this I reversed the process I did in the first one and did the same thing to get these number to be whole number from binary. EX. 1101 (1 x 2^3) (0 x 2^2)
