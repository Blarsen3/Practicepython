# %% [markdown]
# # CHP 9 Ex questions.

# %% [markdown]
# ## Programming Ex
# # Question 5: Word frequency
# Write a program that reads the contents of a text file. The program should create a dictionary in which the keys are the individual words found in the file and the values are the number of times each word appears. For example, if the word “the” appears 128 times, the dictionary would contain an element with  as the key and 128 as the value. The program should either display the frequency of each word or create a second file containing a list of each word and its frequency.

# %% [markdown]
# ## FIrst we want to start by writing a file input and output value and on top of that also write a dictonary and read the input file and then use the whole file.

# %%
def count_word_frequencies(input_file, output_file=None): 
    # Dictionary to store word frequencies
    word_freq = {}
    # Read the input file
    with open(input_file, 'r') as file:
        # Read entire content of the file
        content = file.read()
        # split the content into words
        words = content.split()
        # Count frequencies of each word 
        for word in words:
            # remove punctuation from the word (if any)
            word = word.strip('.,!?-').lower()
            # Update the dictonary
            if word:
                if word in word_freq:
                    word_freq[word] += 1
                else:
                    word_freq[word] = 1

# %% [markdown]
# ### CHeckpoint and prediction for the code so far. This code will not work because I am still writing it znf will finish it and explain below

# %% [markdown]
# ### Next below I will use the code and finish it by displaying andweriting the word dictionarys and showing some example usage.

# %%
def count_word_frequencies(input_file, output_file=None):
    # Dictionary to store word frequencies
    word_freq = {}

    # Read the input file
    with open(input_file, 'r') as file:
        # Read entire content of the file
        content = file.read()

        # Split the content into words
        words = content.split()

        # Count frequency of each word
        for word in words:
            # Remove punctuation marks from the word (if any)
            word = word.strip('.,!?-').lower()
            
            # Update the dictionary
            if word:
                if word in word_freq:
                    word_freq[word] += 1
                else:
                    word_freq[word] = 1
    
    # Display or write the word frequencies
    if output_file:
        with open(output_file, 'w') as file:
            for word, freq in word_freq.items():
                file.write(f"{word}: {freq}\n")
        print(f"Word frequencies written to {output_file}")
    else:
        for word, freq in word_freq.items():
            print(f"{word}: {freq}")

# Example usage:
input_file = 'sample.txt'
output_file = 'word_frequencies.txt'

count_word_frequencies(input_file, output_file)

# %% [markdown]
# ### My prediction is that thsi code iwll work and it will read the contents of a text file. The program should create a dictionary in which the keys are the individual words found in the file and the values are the number of times each word appears
