# %% [markdown]
# # Programming Ex question 13

# %% [markdown]
# A vineyard owner is planting several new rows of grapevines, and needs to know how many grapevines to plant in each row. She has determined that after measuring the length of a future row, she can use the following formula to calculate the number of vines that will fit in the row, along with the trellis end-post assemblies that will need to be constructed at each end of the row:The terms in the formula are:V is the number of grapevines that will fit in the row.R is the length of the row, in feet.E is the amount of space, in feet, used by an end-post assembly.S is the space between vines, in feet.Write a program that makes the calculation for the vineyard owner. The program should ask the user to input the following:
#
# The length of the row, in feet
#
# The amount of space used by an end-post assembly, in feet
#
# The amount of space between the vines, in feet
#
# Once the input data has been entered, the program should calculate and display the number of grapevines that will fit in the row.

# %% [markdown]
# ### To start we have to go down and identify what the variables should calculate.

# %%
R = int(input("Enter length of the row (in feet): "))
##This chooses the variable R which represents length of row
E = int(input("Enter amount of space taken by one end-post assembly (in feet): "))

# Take input for amount of space between the vines
S = int(input("Enter the amount of space between the vines (in feet): "))

# Apply the formula to calculate the no. of vines
V = (R - 2*E)/S

# Print the no. of vines
print("The no. of vines that can be planted in the given row: {}".format(int(V)))
# After this you should be done and be able to enter any variable

# %% [markdown]
# I predict that this code will work for any number of feet, space, with basically any number. I took enough time writing it on Spyder and double checked everything.
# ### This is a prediction that it will work and will present us with:
# Enter a length(in feet): Type any number
# The maount of space between the vines: any number
# Amount of space taken by a post: 2
# apply formula
# and print : The no. of vines that can be planted in the given row:
