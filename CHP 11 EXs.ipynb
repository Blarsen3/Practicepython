# %% [markdown]
# # CHP 11 Exercise
# ## Programming Exercise's

# %% [markdown]
# ## Question 1: Employee and productionworker classes
# Write an Employee class that keeps data attributes for the following pieces of information:
# Employee name
# Employee number
#
#  Next, write a class named ProductionWorker that is a subclass of the Employee class. The ProductionWorker class should keep data attributes for the following information:
#
# Shift number (an integer, such as 1, 2, or 3)
# Hourly pay rate
#
# The workday is divided into two shifts: day and night. The shift attribute will hold an integer value representing the shift that the employee works. The day shift is shift 1 and the night shift is shift 2. Write the appropriate accessor and mutator methods for each class.
#
# Once you have written the classes, write a program that creates an object of the ProductionWorker class and prompts the user to enter data for each of the object’s data attributes. Store the data in the object, then use the object’s accessor methods to retrieve it and display it on the screen.

# %% [markdown]
# ## First you are going to want to make the class for the employee and the production worker and thats the first step in this code before you can get to defining a main Lets do that below.

# %%
# This is me identifying the class 
class Employee:
    def __init__(self, emp_name, emp_number):
        self.emp_name = emp_name
        self.emp_number = emp_number
    
    def get_emp_name(self):
        return self.emp_name
    
    def get_emp_number(self):
        return self.emp_number
    
    def set_emp_name(self, emp_name):
        self.emp_name = emp_name
    
    def set_emp_number(self, emp_number):
        self.emp_number = emp_number

class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_number, hourly_rate):
        super().__init__(emp_name, emp_number)
        self.shift_number = shift_number
        self.hourly_rate - hourly_rate

    def get_shift_number(self):
        return self.shift_number

    def get_hourly_rate(self):
        return self.hourly_rate

    def set_shift_number(self, shift_number):
        self.shift_number = shift_number

    def set_hourly_rate(self, hourly_rate):
        self.hourly_rate = hourly_rate

# %% [markdown]
# ### I predict that this will work and not say anything because its jus the class we were defining the class now we have to call and define the main in the next set of code and then combine them.

# %% [markdown]
# ## Now I will start defining the main and making the next section of code.

# %%
def main():
    # Prompt user for employee data
    emp_name = input("Enter employee name: ")
    emp_number = input("Enter employee number: ")
    shift_number = int(input("Enter shift number (1 for day shift, 2 for night shift): "))
    hourly_rate = float(input("Enter hourly pay rate: "))

    # Create ProductionWorker object
    worker = ProductionWorker(emp_name, emp_number, shift_number, hourly_rate)

    # Display information acessor methods 
    print("\nEmployee Information:")
    print("name:", worker.get_emp_name())
    print("Employee Number:", worker.get_emp_number())
    if worker.get_shift_number() == 1:
        print("Shift: Day") 
    elif worker.get_shift_number() == 2:
        print("Shift: Night")
    else:
        print("Shift: Invalid shift number")
    print("Hourly Pay Rate: $", worker.get_hourly_rate())

if __name__ == "__main__":
    main()

# %% [markdown]
# ### I predict that this will work and will do what uis asked for in the question and below I will combine them to make them one code

# %%
# This is me identifying the class 
class Employee:
    def __init__(self, emp_name, emp_number):
        self.emp_name = emp_name
        self.emp_number = emp_number
    
    def get_emp_name(self):
        return self.emp_name
    
    def get_emp_number(self):
        return self.emp_number
    
    def set_emp_name(self, emp_name):
        self.emp_name = emp_name
    
    def set_emp_number(self, emp_number):
        self.emp_number = emp_number


class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_number, hourly_rate):
        super().__init__(emp_name, emp_number)
        self.shift_number = shift_number
        self.hourly_rate = hourly_rate
    
    def get_shift_number(self):
        return self.shift_number
    
    def get_hourly_rate(self):
        return self.hourly_rate
    
    def set_shift_number(self, shift_number):
        self.shift_number = shift_number
    
    def set_hourly_rate(self, hourly_rate):
        self.hourly_rate = hourly_rate


def main():
    # Prompt user for employee data
    emp_name = input("Enter employee name: ")
    emp_number = input("Enter employee number: ")
    shift_number = int(input("Enter shift number (1 for day shift, 2 for night shift): "))
    hourly_rate = float(input("Enter hourly pay rate: "))

    # Create ProductionWorker object
    worker = ProductionWorker(emp_name, emp_number, shift_number, hourly_rate)

    # Display information using accessor methods
    print("\nEmployee Information:")
    print("Name:", worker.get_emp_name())
    print("Employee Number:", worker.get_emp_number())
    if worker.get_shift_number() == 1:
        print("Shift: Day")
    elif worker.get_shift_number() == 2:
        print("Shift: Night")
    else:
        print("Shift: Invalid shift number")
    print("Hourly Pay Rate: $", worker.get_hourly_rate())

if __name__ == "__main__":
    main()

# %% [markdown]
# # Question 3: Person and customer classes
# Write a class-named person with data attributes for a person’s name, address, and telephone number. Next, write a class named Customer that is a subclass of the person class. The Customer class should have a data attribute for a customer number, and a Boolean data attribute indicating whether the customer wishes to be on a mailing list. Demonstrate an instance of the Customer class in a simple program.

# %% [markdown]
# ## First we are going to want to start with identifying a class again for all the stuff it wants in the class Ill explain as I code below
