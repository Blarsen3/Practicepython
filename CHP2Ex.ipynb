# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# ## Algorithm Workbench - Number 12
# We're presented with a print function call and asked what the output will be.

# %%
print('George', 'John', 'Paul', 'Ringo', sep='@')
